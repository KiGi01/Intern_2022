# %%
"""
-----------------  Question  -----------------
1~1000에서 각 숫자의 개수 구하기

예로 10 ~ 15 까지의 각 숫자의 개수를 구해보자
- 10 = 1, 0
- 11 = 1, 1
- 12 = 1, 2
- 13 = 1, 3
- 14 = 1, 4
- 15 = 1, 5
그러므로 이 경우의 답은 0:1개, 1:7개, 2:1개, 3:1개, 4:1개, 5:1개
----------------------------------------------
"""

# 과제 1. 10~15까지의 각 숫자 개수를 출력하세요(1). 
## 출력 : 0 = 1개, 1 = 7개, 2 = 1개, 3 = 1개, 4 = 1개, 5 = 1개

total0 = 0
total1 = 0
total2 = 0
total3 = 0
total4 = 0
total5 = 0

for i in range (10, 16):
    a = list(str(i))
    for m in a:
        if '0' in m:
            total0+= 1
    for m in a:
        if '1' in m:
            total1+= 1
    for m in a:
        if '2' in m:
            total2+= 1
    for m in a:
        if '3' in m:
            total3+= 1
    for m in a:
        if '4' in m:
            total3+= 1
    for m in a:
        if '5' in m:
            total3+= 1

print('0=%d개, '%total0, '1=%d개, '%total1, '2=%d개, '%total2, '3=%d개, '%total3, '4=%d개, '%total4, '5=%d개'%total5)

# 과제 2. 10~15까지의 각 숫자 개수를 출력하세요(2).
## 출력 : 0 = 1개, 1 = 7개, 2 = 1개, 3 = 1개, 4 = 1개, 5 = 1개, 6 = 0개, 7 = 0개, 8 = 0개, 9 = 0개

total0 = 0
total1 = 0
total2 = 0
total3 = 0
total4 = 0
total5 = 0
total6 = 0
total7 = 0
total8 = 0
total9 = 0

for i in range (10, 16):
    a = list(str(i))
    for m in a:
        if '0' in m:
            total0+= 1
    for m in a:
        if '1' in m:
            total1+= 1
    for m in a:
        if '2' in m:
            total2+= 1
    for m in a:
        if '3' in m:
            total3+= 1
    for m in a:
        if '4' in m:
            total4+= 1
    for m in a:
        if '5' in m:
            total5+= 1
    for m in a:
        if '6' in m:
            total6+= 1
    for m in a:
        if '7' in m:
            total7+= 1
    for m in a:
        if '8' in m:
            total8+= 1
    for m in a:
        if '9' in m:
            total9+= 1


print('0=%d개, '%total0, '1=%d개, '%total1, '2=%d개, '%total2, '3=%d개, '%total3, '4=%d개, '%total4, '5=%d개, '%total5, '6=%d개, '%total6, '7=%d개, '%total7, '8=%d개, '%total8, '9=%d개'%total9)

# 과제 3. 1~1000까지의 각 숫자 개수를 출력하세요
## 출력 : 0 = 192개, 1 = 301개, 2 = 300개, 3 = 300개, 4 = 300개, 5 = 300개, 6 = 300개, 7 = 300개, 8 = 300개, 9 = 300개 

total0 = 0
total1 = 0
total2 = 0
total3 = 0
total4 = 0
total5 = 0
total6 = 0
total7 = 0
total8 = 0
total9 = 0

for i in range (1, 1001):
    a = list(str(i))
    for m in a:
        if '0' in m:
            total0+= 1
    for m in a:
        if '1' in m:
            total1+= 1
    for m in a:
        if '2' in m:
            total2+= 1
    for m in a:
        if '3' in m:
            total3+= 1
    for m in a:
        if '4' in m:
            total4+= 1
    for m in a:
        if '5' in m:
            total5+= 1
    for m in a:
        if '6' in m:
            total6+= 1
    for m in a:
        if '7' in m:
            total7+= 1
    for m in a:
        if '8' in m:
            total8+= 1
    for m in a:
        if '9' in m:
            total9+= 1


print('0=%d개, '%total0, '1=%d개, '%total1, '2=%d개, '%total2, '3=%d개, '%total3, '4=%d개, '%total4, '5=%d개, '%total5, '6=%d개, '%total6, '7=%d개, '%total7, '8=%d개, '%total8, '9=%d개'%total9)
